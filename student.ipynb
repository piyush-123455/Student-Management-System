# %%
students=[]

# %%
def add_student():
    roll=input('Enter Roll Number:')
    name=input('Enter Name:')
    age=input('Enter Age:')
    course=input("Enter Course:")
    student={'Roll':roll,'Name':name,'Age':age,'Course':course}
    students.append(student)
    print("Student Added Sucessfully....")

# %%
def view_students():
    if len(students)==0:
        print("No Students Record found...")
    else:
        print('\nStudents Records')
        print('-'*30)

        for student in students:
            print('Roll  :',student['Roll'])
            print('Name  :',student['Name'])
            print('Age   :',student["Age"])
            print('Course :',student['Course'])
            print('_'*30)

# %%
def search_student():
    roll=input("Enter Roll Number to Search:")
    for student in students:
        if student['Roll']== roll:
            print("\nStudent Found")
            print(student)
            return

    print("Student not Found...")

# %%
def update_student():
    roll=input("Enter Roll Number to Update:")
    for student in students:
        if student["Roll"]== roll:
            student["Name"]=input('Enter New Name:')
            student["Age"]=input("Enter New Age:")
            student['Course']=input("Enter New Course:")
            print('Student Updated Successfully......')
            return
    print('Student Not Found....')

# %%
def delete_student():
    roll=input('Enter Roll Number to Delete:')
    for student in students:
        if student['Roll']==roll:
            students.remove(student)
            print("Student Deleted Successfully...")
            return
    print('Student not Found...')

# %%
while True:
    print('\n----|------|------|----- Student Management System ----|-----|------|---------')
    print('1. Add Student')
    print("2. View Student")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print('6. Exit')
    choice=input('Enter your Choice:-')
    if choice=='1':
        add_student()
    elif choice=='2':
        view_students()
    elif choice=='3':
        search_student()
    elif choice=='4':
        update_student()
    elif choice=='5':
        delete_student()
    elif choice=='6':
        print('======== THANK YOU ===========')
        break
    else:
        print('Invalid Choice!! Please Try Again......')
# Out:
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 2
# No Students Record found...
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206100
# Enter Name: Pratyusha Sahoo
# Enter Age: 19
# Enter Course: AIML
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206094
# Enter Name: Piyush Kumar
# Enter Age: 19
# Enter Course: AIML
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206099
# Enter Name: Pratyush Sahoo
# Enter Age: 18
# Enter Course: Data Analytic
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206092
# Enter Name: Omm Prakash Patnaik
# Enter Age: 19
# Enter Course: Python
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206080
# Enter Name: Madhabananda Patra
# Enter Age: 18
# Enter Course: Java
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206088
# Enter Name: Nitish Behera
# Enter Age: 19
# Enter Course: AIML
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206087
# Enter Name: Nigamananda Sahoo
# Enter Age: 20
# Enter Course: Python
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 1
# Enter Roll Number: 2401206093
# Enter Name: Omm Sibananda Dixit
# Enter Age: 20
# Enter Course: Oops
# Student Added Sucessfully....
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 2
# Students Records
# ------------------------------
# Roll  : 2401206100
# Name  : Pratyusha Sahoo
# Age   : 19
# Course : AIML
# ______________________________
# Roll  : 2401206094
# Name  : Piyush Kumar
# Age   : 19
# Course : AIML
# ______________________________
# Roll  : 2401206099
# Name  : Pratyush Sahoo
# Age   : 18
# Course : Data Analytic
# ______________________________
# Roll  : 2401206092
# Name  : Omm Prakash Patnaik
# Age   : 19
# Course : Python
# ______________________________
# Roll  : 2401206080
# Name  : Madhabananda Patra
# Age   : 18
# Course : Java
# ______________________________
# Roll  : 2401206088
# Name  : Nitish Behera
# Age   : 19
# Course : AIML
# ______________________________
# Roll  : 2401206087
# Name  : Nigamananda Sahoo
# Age   : 20
# Course : Python
# ______________________________
# Roll  : 2401206093
# Name  : Omm Sibananda Dixit
# Age   : 20
# Course : Oops
# ______________________________
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 3
# Enter Roll Number to Search: 2401206100
# Student Found
# {'Roll': '2401206100', 'Name': 'Pratyusha Sahoo', 'Age': '19', 'Course': 'AIML'}
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 3
# Enter Roll Number to Search: 240120670
# Student not Found...
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 4
# Enter Roll Number to Update: 2401206080
# Enter New Name: Madhabananda Patra
# Enter New Age: 18
# Enter New Course: AIML
# Student Updated Successfully......
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 2
# Students Records
# ------------------------------
# Roll  : 2401206100
# Name  : Pratyusha Sahoo
# Age   : 19
# Course : AIML
# ______________________________
# Roll  : 2401206094
# Name  : Piyush Kumar
# Age   : 19
# Course : AIML
# ______________________________
# Roll  : 2401206099
# Name  : Pratyush Sahoo
# Age   : 18
# Course : Data Analytic
# ______________________________
# Roll  : 2401206092
# Name  : Omm Prakash Patnaik
# Age   : 19
# Course : Python
# ______________________________
# Roll  : 2401206080
# Name  : Madhabananda Patra
# Age   : 18
# Course : AIML
# ______________________________
# Roll  : 2401206088
# Name  : Nitish Behera
# Age   : 19
# Course : AIML
# ______________________________
# Roll  : 2401206087
# Name  : Nigamananda Sahoo
# Age   : 20
# Course : Python
# ______________________________
# Roll  : 2401206093
# Name  : Omm Sibananda Dixit
# Age   : 20
# Course : Oops
# ______________________________
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 5
# Enter Roll Number to Delete: 2401206092
# Student Deleted Successfully...
#
# ----|------|------|----- Student Management System ----|-----|------|---------
# 1. Add Student
# 2. View Student
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your Choice:- 6
# ======== THANK YOU ===========
